# %%
# %pip install pytesseract
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.6 MB 4.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.6 MB 8.1 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.6 MB 7.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 6.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 6.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 4.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 4.9 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 4.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 4.6 MB/s eta 0:00:01
# ...

# %%
from PIL import Image
import pytesseract

# %%
# !pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ------ --------------------------------- 0.3/1.5 MB 7.9 MB/s eta 0:00:01
#      -------------------- ------------------- 0.8/1.5 MB 9.6 MB/s eta 0:00:01
#      ------------------------ --------------- 0.9/1.5 MB 7.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.1/1.5 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 1.3/1.5 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 5.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mahimna\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mahimna\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
import PyPDF2
import docx
from IPython.display import display
import ipywidgets as widgets
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# def process_pdf(file_path):
#     with pdfplumber.open(file_path) as pdf:
#         text = ''
#         for page in pdf.pages:
#             text += page.extract_text()
#     return text

# def handle_pdf_upload(change):
#     uploaded_file = change['new']
#     if uploaded_file is not None:
#         with open(uploaded_file['metadata']['name'], 'wb') as f:
#             f.write(uploaded_file['content'])
#         display(widgets.HTML(value=f'<b>Uploaded PDF file:</b> {uploaded_file["metadata"]["name"]}'))
#         # Now you can process the PDF file
#         text = process_pdf(uploaded_file['metadata']['name'])
#         print(text)  # Print the extracted text

# # Create a file upload widget
# file_upload = widgets.FileUpload(accept='.pdf', multiple=False)

# # Attach the handle_pdf_upload function to the file upload widget
# file_upload.observe(handle_pdf_upload, names='value')

# # Display the file upload widget
# display(file_upload)
# Out:
# FileUpload(value=(), accept='.pdf', description='Upload')

# %%
def extract_text_from_pdf(file_path):
    with open(file_path, "rb") as f:
        pdf_reader = PyPDF2.PdfReader(f)
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text()
        return text

def extract_text_from_docx(file_path):
    doc = docx.Document(file_path)
    text = " ".join([paragraph.text for paragraph in doc.paragraphs])
    return text

# %%
def extract_text_from_file(file_path):
    file_extension = file_path.split(".")[-1]

    if file_extension == "pdf":
        return extract_text_from_pdf(file_path)
    elif file_extension in ["doc", "docx"]:
        return extract_text_from_docx(file_path)
    else:
        raise ValueError(f"Unsupported file format: {file_extension}")

# %%
file_path = "C:/Users/Mahimna/Downloads/NYSE_HLF_2022.pdf"
text = extract_text_from_file(file_path)

# %%
def clean_text(text):
    # Lowercase the text
    text = text.lower()
    # Tokenize the text
    words = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    # Remove special characters
    filtered_words = [word for word in filtered_words if word.isalpha()]
    # Join the words back into a string
    cleaned_text = ' '.join(filtered_words)
    return cleaned_text

cleaned_text = clean_text(text)
print(cleaned_text)
# Out:
# annual report shareholders know coming pandemic caused many companies relook operations year change herbalife well year challenge every challenge great opportunity icame back herbalife believe passionately herbalife provides healthand income since returning herbalife along management team distributor leaders around world embarked journey expand content enhance business opportunity modernize brand andexpand digital platform aim reach customers provide distributors better operate business vision world premier health wellness company andcommunity write distributor leaders around world traveling los angeles meet together first time three years learn share innovate build path forward time us reconnect build strategic plan provide growth digital transformation herbalife one enhance company two main platforms content opportunity content product obesity levels hitting record highs around globe greater demand health wellness support plans grow product portfolio daily nutrition productswith ex
# ...
